# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data_File.csv")
df
# Out:
#     Variable_A  Variable_B  Variable_C  Variable_D Variable_E
# 0          6.0         148          72          35          A
# 1          1.0          85          66          29          A
# 2          8.0         183          64           0          B
# 3          1.0          89          66          23          B
# 4          0.0         137          40          35          C
# 5          5.0         116          74           0          A
# 6          3.0          78          50          32          C
# 7         10.0         115           0           0          A
# 8          2.0         197          70          45          C
# 9          NaN         125          96           0          C
# 10         4.0         110          92           0          B
# 11        10.0         168          74           0          A
# 12         NaN         139          80           0          A
# 13         1.0         189          60          23          C

# %% [markdown]
# ### Columns

# %%
df.columns = ["A","B","C"] # Works only if you change all columns name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df.columns = ["A","B","C"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# ...

# %%
df.columns = ["A","B","C","D","E"] # works here if changed all names

# %%
df.rename(columns = {"A": "A_new", "B":"B_new"}, inplace=True) # else use this method

# %%
df
# Out:
#     A_new  B_new   C   D  E
# 0     6.0    148  72  35  A
# 1     1.0     85  66  29  A
# 2     8.0    183  64   0  B
# 3     1.0     89  66  23  B
# 4     0.0    137  40  35  C
# 5     5.0    116  74   0  A
# 6     3.0     78  50  32  C
# 7    10.0    115   0   0  A
# 8     2.0    197  70  45  C
# 9     NaN    125  96   0  C
# 10    4.0    110  92   0  B
# 11   10.0    168  74   0  A
# 12    NaN    139  80   0  A
# 13    1.0    189  60  23  C

# %%
df.columns = ["A","B","C","D","E"]

# %% [markdown]
# #### New Columns

# %%
mean = df["A"].mean()
df["A"] = df["A"].fillna(mean)

# %%
# Creating new columns
df["F"] =  df["A"] + df["B"]+ df["C"]+ df["D"]

# %%
df.head()
# Out:
#      A    B   C   D  E      F
# 0  6.0  148  72  35  A  261.0
# 1  1.0   85  66  29  A  181.0
# 2  8.0  183  64   0  B  255.0
# 3  1.0   89  66  23  B  179.0
# 4  0.0  137  40  35  C  212.0

# %% [markdown]
# #### Delete Column

# %%
# drop()
# axis = 0 for rows
# axis = 1 for columns

# %%
df.drop(["F"],axis = 1, inplace = True)

# %%
df.head()
# Out:
#      A    B   C   D  E
# 0  6.0  148  72  35  A
# 1  5.0   85  66  29  A
# 2  8.0  183  64   0  B
# 3  1.0   89  66  23  B
# 4  0.0  137  40  35  C

# %% [markdown]
# #### Delete Row

# %%
df.drop(2,axis = 0).head()
# Out:
#      A    B   C   D  E
# 0  6.0  148  72  35  A
# 1  5.0   85  66  29  A
# 3  1.0   89  66  23  B
# 4  0.0  137  40  35  C
# 5  5.0  116  74   0  A

# %% [markdown]
# #### Assign Values

# %%
df.loc[1,"A"] = 5

# %%
df.head()
# Out:
#      A    B   C   D  E
# 0  6.0  148  72  35  A
# 1  5.0   85  66  29  A
# 2  8.0  183  64   0  B
# 3  1.0   89  66  23  B
# 4  0.0  137  40  35  C

# %% [markdown]
# #### Copy Values

# %%
# copy()
df_copy = df.copy()

# %% [markdown]
# #### Concat

# %%
#concat()

rowWiseConcat = pd.concat([df,df_copy], axis = 0)
colWiseConcat = pd.concat([df,df_copy], axis = 1)

print("Shape of DF: ", df.shape)

print("Shape of Row Concat: ", rowWiseConcat.shape)
print("Shape of Col Concat: ", colWiseConcat.shape)
# Out:
# Shape of DF:  (14, 5)
# Shape of Row Concat:  (28, 5)
# Shape of Col Concat:  (14, 10)

# %%
rowWiseConcat
# Out:
#         A    B   C   D  E
# 0    6.00  148  72  35  A
# 1    5.00   85  66  29  A
# 2    8.00  183  64   0  B
# 3    1.00   89  66  23  B
# 4    0.00  137  40  35  C
# 5    5.00  116  74   0  A
# 6    3.00   78  50  32  C
# 7   10.00  115   0   0  A
# 8    2.00  197  70  45  C
# 9    4.25  125  96   0  C
# 10   4.00  110  92   0  B
# 11  10.00  168  74   0  A
# 12   4.25  139  80   0  A
# 13   1.00  189  60  23  C
# 0    6.00  148  72  35  A
# 1    5.00   85  66  29  A
# 2    8.00  183  64   0  B
# 3    1.00   89  66  23  B
# 4    0.00  137  40  35  C
# 5    5.00  116  74   0  A
# 6    3.00   78  50  32  C
# 7   10.00  115   0   0  A
# 8    2.00  197  70  45  C
# 9    4.25  125  96   0  C
# 10   4.00  110  92   0  B
# 11  10.00  168  74   0  A
# 12   4.25  139  80   0  A
# 13   1.00  189  60  23  C

# %%
colWiseConcat
# Out:
#         A    B   C   D  E      A    B   C   D  E
# 0    6.00  148  72  35  A   6.00  148  72  35  A
# 1    5.00   85  66  29  A   5.00   85  66  29  A
# 2    8.00  183  64   0  B   8.00  183  64   0  B
# 3    1.00   89  66  23  B   1.00   89  66  23  B
# 4    0.00  137  40  35  C   0.00  137  40  35  C
# 5    5.00  116  74   0  A   5.00  116  74   0  A
# 6    3.00   78  50  32  C   3.00   78  50  32  C
# 7   10.00  115   0   0  A  10.00  115   0   0  A
# 8    2.00  197  70  45  C   2.00  197  70  45  C
# 9    4.25  125  96   0  C   4.25  125  96   0  C
# 10   4.00  110  92   0  B   4.00  110  92   0  B
# 11  10.00  168  74   0  A  10.00  168  74   0  A
# 12   4.25  139  80   0  A   4.25  139  80   0  A
# 13   1.00  189  60  23  C   1.00  189  60  23  C

# %% [markdown]
# #### Group By

# %%
# Group By
df2 = pd.read_csv("Data_File.csv")

# %%
df2.groupby("Variable_E").mean()
# Out:
#             Variable_A  Variable_B  Variable_C  Variable_D
# Variable_E
# A             6.400000  128.500000        61.0   10.666667
# B             4.333333  127.333333        74.0    7.666667
# C             1.500000  145.200000        63.2   27.000000

# %%
# Show data to only selected columns
df2.groupby("Variable_E")[["Variable_A","Variable_B"]].mean()
# Out:
#             Variable_A  Variable_B
# Variable_E
# A             6.400000  128.500000
# B             4.333333  127.333333
# C             1.500000  145.200000

# %% [markdown]
# ##### Value_Counts

# %%
df2.groupby("Variable_E").count()
# Out:
#             Variable_A  Variable_B  Variable_C  Variable_D
# Variable_E
# A                    5           6           6           6
# B                    3           3           3           3
# C                    4           5           5           5

# %%
df2["Variable_E"].value_counts()
# Out:
# A    6
# C    5
# B    3
# Name: Variable_E, dtype: int64

# %% [markdown]
# ## Homework

# %%
rc = pd.concat([df,colWiseConcat], axis = 0)
rc
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 rc = pd.concat([df,colWiseConcat], axis = 0)
#       2 rc
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
# ...

# %%
print(colWiseConcat.shape,rowWiseConcat.shape)
cc = pd.concat([colWiseConcat,rowWiseConcat], axis = 1)
cc
# Out:
# (14, 10) (28, 5)
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [105], in <cell line: 2>()
#       1 print(colWiseConcat.shape,rowWiseConcat.shape)
# ----> 2 cc = pd.concat([colWiseConcat,rowWiseConcat], axis = 1)
#       3 cc
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
# ...

# %%
df = pd.read_csv("Data_File.csv")

# %%
df1 = df.copy()
df2 = df.copy()

df1 = df1.drop([1,6], axis = 0)
df2 = df2.drop(["Variable_A","Variable_B"], axis = 1)

df.shape,df1.shape,df2.shape
# Out:
# ((14, 5), (12, 5), (14, 3))

# %%
rc = pd.concat([df,df1], axis = 0)
rc1 = pd.concat([df,df2], axis = 0)
cc = pd.concat([df,df1], axis = 1)
cc1 = pd.concat([df,df2], axis = 1)

rc.shape, rc1.shape, cc.shape, cc1.shape
# Out:
# ((26, 5), (28, 5), (14, 10), (14, 8))
